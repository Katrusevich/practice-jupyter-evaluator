# %% [markdown]
# # Тестове завдання

# %%
def add(a, b):
    return a + b

# %%
assert add(2, 3) == 5
assert add(-1, 1) == 0

# %%
def multiply(a, b):
    return a * b

# %%
assert multiply(3, 4) == 12
